# %% [markdown]
# # <center>Pandas Assignment</center>

# %% [markdown]
# Import pandas and numpy with their aliases

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Create a variable a = pd.Series([ 100, 200, 300, 400])

# %%
# a =
a = pd.Series([100,200,300,400])

# %% [markdown]
# Print a, and data type

# %%
print(a)
print(a.dtype)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64
# int64

# %% [markdown]
# Using indexing access the element 300 from the series a.

# %%
print(a[2])
# Out:
# 300

# %% [markdown]
# What are the values of index for series a?

# %%
print(a.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# Change the index to  ['c', 'a', 'b', 'd']

# %%
a.index = ['c','a','b','d']
print(a)
# Out:
# c    100
# a    200
# b    300
# d    400
# dtype: int64

# %% [markdown]
# Access the value in the series with index 'd'

# %%
print(a['d'])
# Out:
# 400

# %% [markdown]
# Sort the values wrt to the index and print it

# %%
a=a.sort_index()
print(a)
# Out:
# a    200
# b    300
# c    100
# d    400
# dtype: int64

# %% [markdown]
# Create a new Pandas Series b having index as 'e', 'f', and 'g' and value 800,450,100 and print it

# %%
# b =
b = pd.Series([800,450,100],index=['e','f','g'])
print(b)
# Out:
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Append b series at the end of a series

# %%
# a=
a=pd.concat([a,b])

# %%
#print a again after appending b into it
print(a)
# Out:
# a    200
# b    300
# c    100
# d    400
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Sort the values in descending order of a and print the index of the sorted series

# %%
# a =
a=a.sort_values(ascending=False)
print(a)
# Out:
# e    800
# f    450
# d    400
# b    300
# a    200
# c    100
# g    100
# dtype: int64

# %%
print(a.index)
# Out:
# Index(['e', 'f', 'd', 'b', 'a', 'c', 'g'], dtype='object')

# %% [markdown]
# ## Pandas DataFrame

# %% [markdown]
# ### Part 1

# %% [markdown]
# Create a pandas dataframe df from the series 'a' that we used in the last section, print the dataframe

# %%
# df =
df = pd.DataFrame(a)
print(df)
# Out:
#      0
# e  800
# f  450
# d  400
# b  300
# a  200
# c  100
# g  100

# %% [markdown]
# What is the shape of the datafarme <br>
# (also, what does it imply?)

# %%
print(df.shape)
# Out:
# (7, 1)

# %% [markdown]
# Hey! remember shape (7,1) implies dataframe has 7 rows and 1 column.

# %% [markdown]
# What is the index of the dataframe, is it same as the series 'a'

# %%
# yep its same as the series.
print(df.index)
# Out:
# Index(['e', 'f', 'd', 'b', 'a', 'c', 'g'], dtype='object')

# %% [markdown]
# print the head and tail of the dataframe. <br>
# Additional - (what does head and tali represent?)

# %%
# head print first 5 row
print(df.head())
# Out:
#      0
# e  800
# f  450
# d  400
# b  300
# a  200

# %%
# tail print last 5 row
print(df.tail())
# Out:
#      0
# d  400
# b  300
# a  200
# c  100
# g  100

# %% [markdown]
# Rename the column of the dataframe as 'points'

# %%
df.columns = ['points']
print(df)
# Out:
#    points
# e     800
# f     450
# d     400
# b     300
# a     200
# c     100
# g     100

# %% [markdown]
# Create another Series 'fruits', which contains random names of fruits from ['orange','mango','apple']. The series should contain 7 elements, randomly selected from ['orange','mango','apple']

# %%
#Create fruits array
fruits = np.random.choice(['orange','mango','apple'],7)
print(fruits)
# Out:
# ['apple' 'orange' 'mango' 'mango' 'orange' 'apple' 'mango']

# %%
#Create series fruits out of fruits array
# fruits =
fruits = pd.Series(fruits)
print(fruits)
# Out:
# 0     apple
# 1    orange
# 2     mango
# 3     mango
# 4    orange
# 5     apple
# 6     mango
# dtype: object

# %% [markdown]
# Change the index of fruits to the index of dataframe df

# %%
fruits.index = df.index
print(fruits)
# Out:
# e     apple
# f    orange
# d     mango
# b     mango
# a    orange
# c     apple
# g     mango
# dtype: object

# %% [markdown]
# Add this fruits series as a new column to the dataframe df with its column name as 'fruits'
# <br>print the head of the dataframe to verify

# %%
df['fruits'] = fruits
print(df.head())
# Out:
#    points  fruits
# e     800   apple
# f     450  orange
# d     400   mango
# b     300   mango
# a     200  orange

# %% [markdown]
# ## Pandas Concatenation

# %% [markdown]
# Create a dataframe  d1 where the cols are  ‘city’ : [‘Chandigarh’, ‘Delhi’, ‘Kanpur’, ‘Chennai’, ‘Manali’ ] and ‘Temperature’ : [15, 22, 20, 26,-2]

# %%
# d1 =
d1 = pd.DataFrame({'city':['Chandigarh', 'Delhi', 'Kanpur', 'Chennai', 'Manali' ],'Temperature':[15, 22, 20, 26,-2]})

# %% [markdown]
# Print(d1)

# %%
print(d1)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# What is the shape of d1.

# %%
print(d1.shape)
# Out:
# (5, 2)

# %% [markdown]
# Set city = d1['city']

# %%
city=d1['city']

# %% [markdown]
# print city <br>
# What is the type of city.

# %%
print(city)
print(type(city))
# Out:
# 0    Chandigarh
# 1         Delhi
# 2        Kanpur
# 3       Chennai
# 4        Manali
# Name: city, dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Create another datafeame 'd2' where the columns are <br>
# 'city' - ['Bengalaru','Coimbatore','Srirangam','Pondicherry'] <br>
# 'Temperature' - [24,35,36,39]

# %%
# d2 =
d2 = pd.DataFrame({'city':['Bengalaru','Coimbatore','Srirangam','Pondicherry'],'Temperature':[24,35,36,39]})

# %% [markdown]
# print the shape of this dataframe

# %%
print(d2.shape)
# Out:
# (4, 2)

# %% [markdown]
# merge the two dataframes together, save it in a new dataframe named 'd3'

# %%
# d3 =
d3 = pd.concat([d1,d2],ignore_index=True)
print(d3)
# Out:
#           city  Temperature
# 0   Chandigarh           15
# 1        Delhi           22
# 2       Kanpur           20
# 3      Chennai           26
# 4       Manali           -2
# 5    Bengalaru           24
# 6   Coimbatore           35
# 7    Srirangam           36
# 8  Pondicherry           39

# %% [markdown]
# Select the part of the dataframe such that it contains cities wherer temp is less then or equal to 20 <br>
# How many cities are there?

# %%
less_temp=d3[d3['Temperature']<=20]
print(less_temp)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 2      Kanpur           20
# 4      Manali           -2

# %% [markdown]
# Select the part of the dataframe such that it contains the cities where tempearature greater than or equal to 35

# %%
grt_temp=d3[d3['Temperature']>=35]
print(grt_temp)
# Out:
#           city  Temperature
# 6   Coimbatore           35
# 7    Srirangam           36
# 8  Pondicherry           39

# %% [markdown]
# ## Applying functions to columns and creating new columns

# %% [markdown]
# We need to create another column in d3, which contains  a boolean value for each city to indicate whether it's a union territory or not.
# - HINT: Chandigarh, Pondicherry and Delhi are only 3 union territories here.

# %%
# write function here
# def is_ut(x):
#     # write code below
# d3['is_ut'] =
def is_ut(x):
    if x in ['Chandigarh','Pondicherry','Delhi']:
        return True
    else:
        return False
d3['is_ut']=d3['city'].apply(is_ut)

# %%
# print d3
print(d3)
# Out:
#           city  Temperature  is_ut
# 0   Chandigarh           15   True
# 1        Delhi           22   True
# 2       Kanpur           20  False
# 3      Chennai           26  False
# 4       Manali           -2  False
# 5    Bengalaru           24  False
# 6   Coimbatore           35  False
# 7    Srirangam           36  False
# 8  Pondicherry           39   True

# %% [markdown]
# The temperatures mentioned in ‘Temperature’ column are mentioned in Celsius, we need another column which contains the same in Fahrenheit.

# %% [markdown]
# HINT -
# - Define a function c_to_f which takes input temp in celsius and returns a value with temperature in Fahrenheit.
# - To check: c_to_f(10) should return 50.

# %%
# write function here
def c_to_f(x):
    return (x*9/5)+32

# %%
# check function c_to_f(10)
c_to_f(10)
# Out:
# 50.0

# %%
# apply function c_to_f to d3 to create a column 'temp_farenhiet'
d3['temp_farenhiet']=d3['Temperature'].apply(c_to_f)

# %%
print(d3)
# Out:
#           city  Temperature  is_ut  temp_farenhiet
# 0   Chandigarh           15   True            59.0
# 1        Delhi           22   True            71.6
# 2       Kanpur           20  False            68.0
# 3      Chennai           26  False            78.8
# 4       Manali           -2  False            28.4
# 5    Bengalaru           24  False            75.2
# 6   Coimbatore           35  False            95.0
# 7    Srirangam           36  False            96.8
# 8  Pondicherry           39   True           102.2

# %% [markdown]
# ## Indexing and selecting rows in DataFrame

# %% [markdown]
# Select subset of the dataframe d1 such that it contains the cities which are union territories.

# %%
city_ut=d3[d3['is_ut']==True]
print(city_ut)
# Out:
#           city  Temperature  is_ut  temp_farenhiet
# 0   Chandigarh           15   True            59.0
# 1        Delhi           22   True            71.6
# 8  Pondicherry           39   True           102.2

# %% [markdown]
# Select a subset of the dataframe d1 such that it contains the cities which only have temperature above 90 Farenhiet.

# %%
city_temp=d3[d3['temp_farenhiet']>90]
print(city_temp)
# Out:
#           city  Temperature  is_ut  temp_farenhiet
# 6   Coimbatore           35  False            95.0
# 7    Srirangam           36  False            96.8
# 8  Pondicherry           39   True           102.2

# %% [markdown]
# Select only the first three rows of the dataframe d1.

# %%
print(d1.head(3))
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20

# %% [markdown]
# Select all the rows and last two columns in the dataframe.

# %%
print(d3.iloc[:,-2:])
# Out:
#    is_ut  temp_farenhiet
# 0   True            59.0
# 1   True            71.6
# 2  False            68.0
# 3  False            78.8
# 4  False            28.4
# 5  False            75.2
# 6  False            95.0
# 7  False            96.8
# 8   True           102.2

# %% [markdown]
# ## Groupby

# %%
# Create a dataframe using dictionary of your choice
# data =
data = {
    'Department': ['IT', 'IT', 'HR', 'HR', 'Finance', 'Finance', 'IT'],
    'Employee': ['A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'Salary': [60000, 65000, 50000, 52000, 70000, 72000, 64000],
    'Experience': [3, 4, 2, 5, 6, 7, 4]
}
df4=pd.DataFrame(data)
print(df4)
# Out:
#   Department Employee  Salary  Experience
# 0         IT        A   60000           3
# 1         IT        B   65000           4
# 2         HR        C   50000           2
# 3         HR        D   52000           5
# 4    Finance        E   70000           6
# 5    Finance        F   72000           7
# 6         IT        G   64000           4

# %%
# Use Groupby of single column with aggregate sum()
dept_sal=df4.groupby('Department')['Salary'].sum()
print(dept_sal)
# Out:
# Department
# Finance    142000
# HR         102000
# IT         189000
# Name: Salary, dtype: int64

# %%
# Use Groupby of single column with aggregate count()
dept_emp=df4.groupby('Department')['Employee'].count()
print(dept_emp)
# Out:
# Department
# Finance    2
# HR         2
# IT         3
# Name: Employee, dtype: int64

# %%
# Use Groupby of single column with aggregate min() and max()
dept_exp=df4.groupby('Department')['Experience'].agg(['min','max'])
print(dept_exp)
# Out:
#             min  max
# Department
# Finance       6    7
# HR            2    5
# IT            3    4

# %%
# Use Groupby of any 2 columns with aggregate mean()
dept_sal_emp=df4.groupby(['Department','Employee'])['Salary'].mean()
print(dept_sal_emp)
dept_sal_mean=df4.groupby(['Department'])['Salary'].mean()
print(dept_sal_mean)
# Out:
# Department  Employee
# Finance     E           70000.0
#             F           72000.0
# HR          C           50000.0
#             D           52000.0
# IT          A           60000.0
#             B           65000.0
#             G           64000.0
# Name: Salary, dtype: float64
# Department
# Finance    71000.0
# HR         51000.0
# IT         63000.0
# Name: Salary, dtype: float64

# %%
# Use Groupby of any 2 columns with aggregate min() and max()
dept_sal_exp=df4.groupby(['Department','Employee'])['Experience'].agg(['min','max'])
print(dept_sal_exp)
dept_exp_agg=df4.groupby(['Department'])['Experience'].agg(['min','max'])
print(dept_exp_agg)
# Out:
#                      min  max
# Department Employee
# Finance    E           6    6
#            F           7    7
# HR         C           2    2
#            D           5    5
# IT         A           3    3
#            B           4    4
#            G           4    4
#             min  max
# Department
# Finance       6    7
# HR            2    5
# IT            3    4

# %% [markdown]
# ## Data Range

# %% [markdown]
# Create a pandas daterange where starting date is 1st of January,2020 and end date is 1st of April 2021, store it in a new variable named 'a'

# %%
# a =
a = pd.date_range(start='2020-01-01',end='2021-04-01')

# %% [markdown]
# print a

# %%
print(a)
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2021-03-23', '2021-03-24', '2021-03-25', '2021-03-26',
#                '2021-03-27', '2021-03-28', '2021-03-29', '2021-03-30',
#                '2021-03-31', '2021-04-01'],
#               dtype='datetime64[ns]', length=457, freq='D')

# %% [markdown]
# What is the len of a?

# %%
print(len(a))
# Out:
# 457

# %% [markdown]
# What is the type of a?

# %%
print(type(a))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
